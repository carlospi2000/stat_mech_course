# %%
from molsim import MonteCarlo
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set up the Monte Carlo simulation
mc = MonteCarlo(
    numberOfParticles=100,
    temperature=1.0,
    boxSize=6.0,
    maxDisplacement=0.5,
    numberOfInitCycles=0,
    numberOfProdCycles=1000,
    sampleFrequency=100,
    seed=12,
)

# Run the Monte Carlo simulation
mc.run()

# %%
# Plot the results
plt.plot(mc.energies, label="Potential energy")

plt.xlabel("Cycles")
plt.ylabel(r"Potential energy, U / $\varepsilon$")

plt.tight_layout()

# %% [markdown]
# Visualize the `movie.pdb` trajectory.

# %%
import nglview as nv
import mdtraj as md

movie = md.load_pdb("movie.pdb")
view = nv.widget.NGLWidget()
view = nv.show_mdtraj(movie)
view.clear_representations()
view.add_representation('spacefill', radius=0.5, color='pink')
view.camera = "orthographic"
view.add_unitcell()
view
